# %% [markdown]
# <!-- pickle -->
# <!-- joblib - same as pickle but faster, more efficient when dealing with more numpy arrays  -->

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# dataframe creation and plotting
df=pd.read_csv("house.csv")
plt.scatter(df['area'], df['price'])
reg=linear_model.LinearRegression()

# %%
# training the model
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
# making prediction
reg.predict([[3000]])
# Out:
# C:\Users\kamal\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23156038.96103896])

# %%
# saving a model using pickle
import pickle

# %%
# storing the model as pickle file
with open('model_pickle','wb') as f:
    pickle.dump(reg,f)

# %%
# using the model
with open('model_pickle','rb') as f:
    mp=pickle.load(f)

# %%
mp.predict([[3000]])
# Out:
# C:\Users\kamal\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23156038.96103896])

# %%
# saving a model using joblib
import joblib

# %%
joblib.dump(reg,'model_joblib')
# Out:
# ['model_joblib']

# %%
mj=joblib.load('model_joblib')

# %%
mj.predict([[3000]])
# Out:
# C:\Users\kamal\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23156038.96103896])
