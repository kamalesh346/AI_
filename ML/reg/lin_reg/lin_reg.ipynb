# %%
# here in linear regression prediction is always continuous

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\kamal\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kamal\appdata\roaming\python\python312\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kamal\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kamal\appdata\roaming\python\python312\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kamal\appdata\roaming\python\python312\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kamal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# dataframe creation and plotting
df=pd.read_csv("house.csv")
plt.scatter(df['area'], df['price'])
reg=linear_model.LinearRegression()

# %%
# training the model
reg.fit(df[['area']],df.price) # 1st argument is 2D
# Out:
# LinearRegression()

# %%
# making prediction
reg.predict([[3000]])
# Out:
# C:\Users\kamal\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23156038.96103896])

# %%
d=pd.read_csv("area.csv")
p=reg.predict(d)
print(p)
# Out:
# [ 3707467.53246753  5033506.49350649  6359545.45454546  7685584.41558442
#   9011623.37662338 10779675.32467533 12547727.27272727 14315779.22077922
#  16083831.16883117 18735909.09090909]

# %%
d['prices']=p
d.to_csv('prediction.csv',index=False)

# %%
# plotting the best fit line 
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
